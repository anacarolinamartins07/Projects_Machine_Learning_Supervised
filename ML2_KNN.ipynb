# %% [markdown]
# <a href="https://colab.research.google.com/github/anacarolinamartins07/Projects_Machine_Learning_Supervised/blob/main/ML2_KNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#knn para regressao de machine learning supervisionado

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/insurance.csv")

# %%
df.head(10)
# Out:
#    age     sex     bmi  children  smoker     region    charges
# 0   19  female  27.900         0       1  southwest  16.884924
# 1   18    male  33.770         1       0  southeast   1.725552
# 2   28    male  33.000         3       0  southeast   4.449462
# 3   33    male  22.705         0       0  northwest  21.984471
# 4   32    male  28.880         0       0  northwest   3.866855
# 5   31  female  25.740         0       0  southeast   3.756622
# 6   46  female  33.440         1       0  southeast   8.240590
# 7   37  female  27.740         3       0  northwest   7.281506
# 8   37    male  29.830         2       0  northeast   6.406411
# 9   60  female  25.840         0       0  northwest  28.923137

# %%
df.describe()
# Out:
#                age          bmi     children       smoker      charges
# count  1338.000000  1338.000000  1338.000000  1338.000000  1338.000000
# mean     39.207025    30.663397     1.094918     0.204783    13.270422
# std      14.049960     6.098187     1.205493     0.403694    12.110011
# min      18.000000    15.960000     0.000000     0.000000     1.121874
# 25%      27.000000    26.296250     0.000000     0.000000     4.740287
# 50%      39.000000    30.400000     1.000000     0.000000     9.382033
# 75%      51.000000    34.693750     2.000000     0.000000    16.639913
# max      64.000000    53.130000     5.000000     1.000000    63.770428

# %%
#pré processamento

# %%
df["smoker"]= df["smoker"].map({'yes':1, 'no':0})

# %%
df["charges"]= df["charges"]/1000

# %%
#validacao e ajuste do modelo

# %%
from sklearn.model_selection import train_test_split

# %%
x= df[["bmi","smoker"]]
y= df["charges"]

# %%
xtreino, xteste, ytreino, yteste= train_test_split(x,y, test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
k=15
knn = KNeighborsRegressor(n_neighbors = k )

# %%
knn.fit(xtreino,ytreino,)
# Out:
# KNeighborsRegressor(n_neighbors=15)

# %%
y_hat= knn.predict(xteste)

# %%
from sklearn.metrics import mean_squared_error

# %%
eqm= mean_squared_error(yteste, y_hat)

# %%
print('O eqm foi: ', round(eqm,2))
# Out:
# O eqm foi:  64.8
